# %% [markdown]
# <a href="https://colab.research.google.com/github/sashabel1/Cloud-tirgul/blob/master/Cloud_Practice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Colab Notebooks"
# Out:
# "Sasha'sNotebook.ipynb"

# %%
import numpy as np
from matplotlib import pyplot as plt

y = np.random.randn(100)
x = [x for x in range(len(y))]

plt.plot(x, y, '-')
plt.fill_between(x, y, 200, where = (y > 195), facecolor='g', alpha=0.6)

plt.title("Sample Plot")
plt.show()

# %%
# @title My Title
name = "Bob" # @param {"type":"string","placeholder":"Name"}
gender = "male" # @param ["male", "female"]
age = 56 # @param {"type":"slider","min":0,"max":120,"step":1}
print(name,gender,age)
# Out:
# Bob male 56

# %%
# %%html
# <style>
# body {
#   background: url('https://lh3.googleusercontent.com/d/1V9cRNTQxY-6j0LcTKMa_p8LaRaK43a0f=w1000') no-repeat center center fixed;
#   background-size: cover;
#     margin: 0;
#     height: 100vh;
#     display: flex;
#     justify-content: center;
#     align-items: center;
#     background-size: 50%; /* Adjust this to make the background smaller */
#     background-attachment: fixed; /* Keeps it in place */
# }
# /* Ensure the flag is centered */
#   .flag-container {
#     display: flex;
#     justify-content: center;
#     align-items: center;
#   }
# </style>
#
# <div class="flag-container">
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
#    <rect x="0" y="250" width="100" height="200" rx="0" style="fill:green; stroke:black; fill-opacity:1.0" />
#    <rect x="100" y="250" width="100" height="200" rx="0" style="fill:white; stroke:black; fill-opacity:1.0;" />
#    <rect x="200" y="250" width="100" height="200" rx="0" style="fill:red; stroke:black; fill-opacity:1.0;" />
# </svg>
# </div>
# Out:
# <style>
# body {
#   background: url('https://lh3.googleusercontent.com/d/1V9cRNTQxY-6j0LcTKMa_p8LaRaK43a0f=w1000') no-repeat center center fixed;
#   background-size: cover;
#     margin: 0;
#     height: 100vh;
#     display: flex;
#     justify-content: center;
#     align-items: center;
#     background-size: 50%; /* Adjust this to make the background smaller */
#     background-attachment: fixed; /* Keeps it in place */
# }
# /* Ensure the flag is centered */
#   .flag-container {
#     display: flex;
#     justify-content: center;
#     align-items: center;
#   }
# </style>
#
# <div class="flag-container">
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
#    <rect x="0" y="250" width="100" height="200" rx="0" style="fill:green; stroke:black; fill-opacity:1.0" />
#    <rect x="100" y="250" width="100" height="200" rx="0" style="fill:white; stroke:black; fill-opacity:1.0;" />
# ...

# %%
# @title Default title text
Name = "" # @param {"type":"string","placeholder":"Name"}
LastName= "" # @param {"type":"string","placeholder":"Last Name"}
email= "" # @param {"type":"string","placeholder":"Email"}
from IPython.core.display import display, HTML

file_path = "/content/drive/MyDrive/students.txt"

with open(file_path, "r") as file:
    students = file.readlines()


student_names = [line.split()[0] for line in students if line.strip()]


dropdown_html = '<label for="students">Select a student:</label>'
dropdown_html += '<select id="students" name="students" style="margin:5px; width:200px;">'


for name in student_names:
    dropdown_html += f'<option value="{name}">{name}</option>'

dropdown_html += '</select>'


display(HTML(dropdown_html))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-8408f8151b57> in <cell line: 0>()
#       7 file_path = "/content/drive/MyDrive/students.txt"
#       8
# ----> 9 with open(file_path, "r") as file:
#      10     students = file.readlines()
#      11
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/students.txt'
